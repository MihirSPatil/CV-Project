# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
# %matplotlib inline

# %%
# img = cv2.imread('/home/mihir/Pictures/zbFZX3l.jpg')
def nothing(x):
    pass

# read the experimental image
img = cv2.imread('/home/mihir/Pictures/zbFZX3l.jpg', 0)
img = cv2.resize(img, (320, 240))

# create trackbar for canny edge detection threshold changes
cv2.namedWindow('canny')

# add ON/OFF switch to "canny"
switch = '0 : OFF \n1 : ON'
cv2.createTrackbar(switch, 'canny', 0, 1, nothing)

# add lower and upper threshold slidebars to "canny"
cv2.createTrackbar('lower', 'canny', 0, 255, nothing)
cv2.createTrackbar('upper', 'canny', 0, 255, nothing)

# Infinite loop until we hit the escape key on keyboard
while(1):

    # get current positions of four trackbars
    lower = cv2.getTrackbarPos('lower', 'canny')
    upper = cv2.getTrackbarPos('upper', 'canny')
    s = cv2.getTrackbarPos(switch, 'canny')

    if s == 0:
        edges = img
    else:
        edges = cv2.Canny(img, lower, upper)

    # display images
#     cv2.imshow('original', img)
    cv2.imshow('canny', edges)
    k = cv2.waitKey(1) & 0xFF
    if k == 27:   # hit escape to quit
        break

cv2.destroyAllWindows()
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# plt.imshow(img)

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
img2 = cv2.imread('/home/mihir/Pictures/alena-aenami-dreamer-1k.jpg')
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
np.shape(img2)
# Out:
# (1080, 1920, 3)

# %%
res = cv2.subtract(img, img2)

# %%
plt.imshow(res)

# %%
res = cv2.bitwise_and(img, img2)
plt.imshow(res)

# %%
res_avg = cv2.add(img, img2)/2

# %%
plt.imshow(res_avg)

# %%
def scale(img,val):
    res = np.multiply(img, val)
    return res

# %%
res = scale(img,3)
plt.imshow(res)

# %%
def merge(a, b, alpha):
    res = cv2.addWeighted(a, alpha, b, 1-alpha,0)
    return res

# %%
res = merge(img,img2,.4)
plt.imshow(res)

# %%
def add_noise(img, sigma):
    out = (np.random.normal(0,1,img.shape)*sigma) + img
    return out

# %%
noise_img = add_noise(img, -5)
plt.imshow(noise_img)

# %%
plt.imshow(abs(cv2.subtract(img2,img)))

# %%
plt.imshow(cv2.absdiff(img, img2))

# %%
plt.imshow(img-img2)

# %%
plt.imshow(img2-img)

# %%
noise = np.random.normal(0,1,10000)
binz = np.linspace(-3,3,100)
plt.hist(noise, bins = binz)
plt.show()

# %%
mini, maxi, minloc, maxloc = cv2.minMaxLoc(cv2.cvtColor(img, cv2.COLOR_BGR2GRAY))
print(mini,maxi, minloc, maxloc)
# Out:
# (0.0, 255.0, (580, 633), (617, 555))
